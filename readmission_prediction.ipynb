# %%
import pandas as pd
import numpy as np

# Create sample healthcare dataset
data = {
    'age': [45, 60, 72, 50, 39, 80, 66, 54],
    'diabetes': [1, 0, 1, 0, 0, 1, 1, 0],
    'hypertension': [1, 1, 0, 0, 1, 1, 0, 0],
    'readmitted': [1, 0, 1, 0, 0, 1, 1, 0]
}

df = pd.DataFrame(data)

print(df)

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = df[['age', 'diabetes', 'hypertension']]
y = df['readmitted']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

print("Model trained successfully")
# Out:
#    age  diabetes  hypertension  readmitted
# 0   45         1             1           1
# 1   60         0             1           0
# 2   72         1             0           1
# 3   50         0             0           0
# 4   39         0             1           0
# 5   80         1             1           1
# 6   66         1             0           1
# 7   54         0             0           0
# Model trained successfully
